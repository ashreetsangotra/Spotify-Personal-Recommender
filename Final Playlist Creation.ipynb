# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
pd.set_option('max_rows',100)
import time
import os
import warnings
warnings.filterwarnings('ignore')
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
import pickle
from tqdm import tqdm

# %% [markdown]
# # Importing Main Spotify Dataset

# %%
df = pd.read_csv('Spotify/data.csv')

# %%
# Set index as track_ids
df.set_index('id',inplace = True)

# %%
# Subset the columns based on our trained model

df = df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms']]

# %% [markdown]
# # Scaling

# %%
# Scale the data before applying the model

scaler = StandardScaler()

df.iloc[:,:] = scaler.fit_transform(df.iloc[:,:])

# %%
df.head()
# Out:
#                         danceability    energy       key  loudness      mode  \
# id
# 6KbQ3uYMLKb5jDxLF7wYDD      0.968662 -1.097999  1.365333 -0.186652  0.641344
# 6KuQTIu1KoTTkLXKrwlLPV     -0.907636 -1.776785  0.796383 -3.014729  0.641344
# 6L63VW0PibdM1HDSBoqnoM      1.202486 -1.004503 -0.057043 -1.509457 -1.559227
# 6M94FkXd15sOAOQYRnWPN8      1.384983 -1.341091 -1.194943 -0.593587 -1.559227
# 6N6tiFZ9vLTSOIxkj8qKrd     -1.871449 -1.064341  1.649808 -0.963288  0.641344
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# id
# 6KbQ3uYMLKb5jDxLF7wYDD    -0.289840      1.332319          1.296562 -0.314998
# 6KuQTIu1KoTTkLXKrwlLPV    -0.319186      1.329664          2.389253 -0.737519
# 6L63VW0PibdM1HDSBoqnoM     5.568626      0.294154         -0.523513 -0.495997
# 6M94FkXd15sOAOQYRnWPN8    -0.009722      1.332319          2.343994 -0.541247
# 6N6tiFZ9vLTSOIxkj8qKrd    -0.344530      1.319044          2.411883 -0.614778
#
#                          valence     tempo  duration_ms
# id
# 6KbQ3uYMLKb5jDxLF7wYDD  0.940924  0.049500    -0.599713
# 6KuQTIu1KoTTkLXKrwlLPV -1.735454 -1.073199     0.418119
# 6L63VW0PibdM1HDSBoqnoM  1.325822 -0.317996    -1.047680
# 6M94FkXd15sOAOQYRnWPN8  0.716082 -0.291114    -0.417454
# 6N6tiFZ9vLTSOIxkj8qKrd -1.763655 -1.783425     3.761300

# %% [markdown]
# # Applying the Model

# %%
# Import the Model

import pickle

loaded_model = pickle.load(open('final_model', 'rb'))

# %%
# Predict on the new dataset
preds = loaded_model.predict_proba(df)

# %%
# Store track_ids in a list
# Subsetting index of songs with probability > 0.8

list_of_songs = list(df.index[preds[:,1] > 0.8])

# %% [markdown]
# # API building to get track info

# %%
import requests
import json
from requests.auth import HTTPBasicAuth

# %%
client_id = 'b107854432764d6fb8104f4b7a494d74'
client_secret = '9ef8de4d0e324edfb26676339b80be32'

# %%
auth_url = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(auth_url, {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# %%
data = pd.DataFrame(index = list_of_songs, columns = ['Song Name', 'Artist Name'])

# %%
i = 0
for item in tqdm(list_of_songs):
    song_info = requests.get(BASE_URL + 'tracks/' + item, headers=headers)
    song_info = song_info.json()
    
    data.iloc[i, 1] = song_info['artists'][0]['name']
    data.iloc[i, 0] = song_info['name']
    
    i = i + 1
# Out:
# 100%|██████████| 63/63 [00:24<00:00,  2.53it/s]

# %%
data
# Out:
#                                                                 Song Name  \
# 1TKwqSq2YTqJ4Aso17FfYR                                      What 'cha Say
# 099Ov2UBeZcckb2Py8o7qa                                               Pain
# 0DQlv289AsGiUJJZL4mviO                                     Little Melonae
# 3LPEU6PFvVal1Iya8I5eU5                                             Creola
# 59FdiKJe5LXnDhKKd6vrI5                                I'll Remember April
# 78rosLrFWoORay8qHATSVk                                I'll Remember April
# 1MmxrJ35NzNxHjPdyKDhut                            Kashmir - 1990 Remaster
# 61g5yH0ig62XhtQ161kEED          In My Time of Dying - Initial / Rough Mix
# 0slsrhWlw0WrrRe1KCVboI                          And the Healing Has Begun
# 66YI1uZX5bqDb760dF5XYh                                          Dark Eyes
# 6GvOBwtPXOYCQPeeEXJ6cW                          Please Be Patient With Me
# 7Lg3OJ4GpYVxo2txulF55X                                      Dream in Blue
# 6q8JYOuYM13UOyBaLYFC08                                 A Night In Tunisia
# 5NAIUPQQ0yWrdPjxIsRvOf                                        Oleo - Live
# 76Gr42u95qinkkdqd3pnZA                                      Packard Goose
# 4Of2tXw58kRjX6jVv6mwUM                                  Love Is a Mystery
# 0pwmqfTWCcDb6aqcVl3iPf                                           Anythin'
# 5G9K17dSw00xM9YUX17pno                                            Phoenix
# 4myr4mVbe6t5vy9Px6FFcI                                  I've Known No War
# 5C3NwXV0A9O7xbyfjoPgA6                                       Highway Girl
# 1TvDbPJqJbYz33UKYjwB1s                    Sounds of the Loop - Remastered
# 5OlgaiQ3rG7LfVGFxeXEl6                     The Dance of Maya - Remastered
# 4ogOUX6MrqfrXhyd90fkCJ                                       Oye Mi Canto
# 0Wa5Q145xoXkfhaCRgA67U                                 Kashmir - Remaster
# 65Q2A0pUf2lznsMaBvieqW                                  The Love Has Gone
# 0yVeWcRjjC8RuK7d5LHCDe                                      Just One Look
# 2nVHqZbOGkKWzlcy1aMbE7                            Kashmir - 1990 Remaster
# 6Vjk8MNXpQpi0F4BefdTyq                                 Kashmir - Remaster
# 0ikz6tENMONtK6qGkOrU3c                        Wake Me up Before You Go-Go
# 4CoSCPlKNrWli7E5kFtbcl                        Little Lies - 2017 Remaster
# 42dsUTJpzMWUJfEkzsbKWl                              When the Music's Over
# 3ZRUhvuUE2lwZF19puKM8P                        Un Hombre Busca a Una Mujer
# 2YQ4R8eICy851TjCdFYUSd                                     Happy Feelin's
# 0xOeB16JDbBJBJKSdHbElT                                   Rebellion (Lies)
# 0sQ594D1EuU66VDdtHBE6j                                     Spanish Harlem
# 35WDTZhAwkoBF65jGTzF2O           Barbarism Begins at Home - 2011 Remaster
# 2JwztiYR35Y8Wvf8rwnQva                                         Lolo Felix
# 0Ka6cMllwgn7TwUyT0La0R                     Turn That Heartbeat Over Again
# 4MKun9QQhoapVvhp2uxJif              Lily, Rosemary and the Jack of Hearts
# 4myr4mVbe6t5vy9Px6FFcI                   The Who
# 5C3NwXV0A9O7xbyfjoPgA6        The Tragically Hip
# 1TvDbPJqJbYz33UKYjwB1s  The Dave Brubeck Quartet
# 5OlgaiQ3rG7LfVGFxeXEl6      Mahavishnu Orchestra
# 4ogOUX6MrqfrXhyd90fkCJ            Gloria Estefan
# 0Wa5Q145xoXkfhaCRgA67U              Led Zeppelin
# 65Q2A0pUf2lznsMaBvieqW               Rick Astley
# 0yVeWcRjjC8RuK7d5LHCDe             Eddie Lovette
# 2nVHqZbOGkKWzlcy1aMbE7              Led Zeppelin
# 6Vjk8MNXpQpi0F4BefdTyq              Led Zeppelin
# 0ikz6tENMONtK6qGkOrU3c                     Wham!
# 4CoSCPlKNrWli7E5kFtbcl             Fleetwood Mac
# 42dsUTJpzMWUJfEkzsbKWl                 The Doors
# 3ZRUhvuUE2lwZF19puKM8P               Luis Miguel
# 2YQ4R8eICy851TjCdFYUSd                      Maze
# 0xOeB16JDbBJBJKSdHbElT               Arcade Fire
# 0sQ594D1EuU66VDdtHBE6j           Aretha Franklin
# 35WDTZhAwkoBF65jGTzF2O                The Smiths
# 2JwztiYR35Y8Wvf8rwnQva          Arsenal Efectivo
# 0Ka6cMllwgn7TwUyT0La0R                Steely Dan
# 4MKun9QQhoapVvhp2uxJif                 Bob Dylan
# 1QGyGePWYz2cs9LsAWwiwE           Charlie Daniels
# 0fZLTsasJCJ2EaaczK2Nob   Queens of the Stone Age
# 5jklyYwzYIY20CiWG5uccu               John Legend
# 2FZv72gyxqvSr4AdQm6gzt      Allman Brothers Band
# 4nsC2PG5fF4dWu2P9isR4m      The Neville Brothers
# 3FPaQv0qldYuF0XD0ziwT8                 Four Tops
# 4EcM86vNf0QIOGkpf4O0UP             Fleetwood Mac
# 6ceffRqL8teDpyYu41UwKm             The Mavericks
# 3Cn1aiqSnvaj3FF4eFT80W                El DeBarge
# 0M7qIbIfd9IQy68DibTqQ9                     Phish
# 0EvqtUYBpFOtAGrfWI2DtL             Andy Montañez
# 6Os7cO6a6UeglnpIKidRjh                Tim McGraw
# 6yRPErtmW2FuTeQ1cvDsrr            Clifford Brown
# 0hWXOGE9h1ECCpWOnDWLbV               Isaac Hayes
# 4ObPmra5m7WJ5DMGmdgLRY               Jethro Tull
# 2JsOn3ljx31GD6PKnVoibo                      Maze
# 1iKWEkFBENe8PcOVXXkXg8              Dolly Parton
# 3Ki1XRwvSJ9UREfeFldVdB               Jethro Tull
# 0s4vE966muxYTw4GXX9ADF                Loose Ends
# 4tmfwZtdmaIu151emh76jN              The Bar-Kays
# 5v2vkoTamoisazJFanHJjk              Led Zeppelin
# 4OLywSlkQFTG8S0G0VGpVh                 Max Roach
# 0VuHj3cmwUZqeXaypQ44vA               Phoebe Snow
# 2M4qkpf3LemaTrXbhbTVdG               Dave Grusin
